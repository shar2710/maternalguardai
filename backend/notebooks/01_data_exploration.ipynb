# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='whitegrid')
plt.rcParams["figure.figsize"]=(12, 6)

df=pd.read_csv('sample_data (1).csv')

print("sape:", df.shape)
df.head()
# Out:
# sape: (2847, 26)
#    blood_pressure_systolic  blood_pressure_diastolic  urine_protein  \
# 0                98.848682                 82.566957       0.014116
# 1               104.939826                 79.865970       0.092633
# 2               112.371092                 87.229983       0.055182
# 3               143.494549                 96.141015       0.753368
# 4               135.895387                 73.512604       0.136254
#
#    platelet_count  liver_enzymes  serum_creatinine        bmi  age  \
# 0          273015      15.431424          0.974706  25.017029   30
# 1          298157      41.407858          0.767449  22.470298   30
# 2          280329      25.268926          0.827158  21.590781   34
# 3          110201      84.065011          1.308336  32.536020   30
# 4          261386      26.274377          0.935389  20.848687   26
#
#     height_cm  weight_kg  ...  urine_creatinine  red_blood_cell_count  parity  \
# ...

# %%
missing=df.isnull().sum().sort_values(ascending=False)
print("missing values per column:\n", missing[missing > 0])
# Out:
# missing values per column:
#  Series([], dtype: int64)

# %%
sns.countplot(x='preeclampsia', data=df)
plt.title('class distribution: preeclampsia (1) vs healthy (0)')
plt.xlabel('preeclampsia')
plt.ylabel('count')
plt.show()

print(df['preeclampsia'].value_counts(normalize=True) * 100)
# Out:
# preeclampsia
# 0    85.528627
# 1    14.471373
# Name: proportion, dtype: float64

# %%
df.describe().T
# Out:
#                            count           mean           std            min  \
# blood_pressure_systolic   2847.0     119.107866     14.173463      90.000000
# blood_pressure_diastolic  2847.0      77.206120     10.523221      50.000000
# urine_protein             2847.0       0.264768      0.493123       0.000000
# platelet_count            2847.0  245177.056551  48384.148599  100000.000000
# liver_enzymes             2847.0      37.128911     21.622929      10.000000
# serum_creatinine          2847.0       0.864452      0.202648       0.500000
# bmi                       2847.0      24.250547      4.660721      18.000000
# age                       2847.0      27.431682      5.036845      18.000000
# height_cm                 2847.0     159.739371      6.861613     140.000000
# weight_kg                 2847.0      61.913462      9.317323      45.000000
# white_blood_cell_count    2847.0    8098.457837   1077.744500    4467.181812
# ...

# %%
selected_features=['age', 'bmi', 'blood_pressure_systolic', 'glucose_level', 'hemoglobin']

df[selected_features].hist(bins=30, figsize=(15, 8), color='green')
plt.suptitle("distribution of selected features")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 12))
corr=df.corr()
sns.heatmap(corr, cmap='coolwarm', annot=False)
plt.title("correlation matrix")
plt.show()

# %%
for feature in ['bmi', 'blood_pressure_systolic', 'glucose_level', 'hemoglobin']:
    sns.boxplot(data=df, x='preeclampsia', y=feature)
    plt.title(f'{feature} v/s preeclampsia')
    plt.show()

# %%
df.corr()['preeclampsia'].sort_values(ascending=False)
# Out:
# preeclampsia                1.000000
# sFlt1_PlGF_ratio            0.793116
# urine_protein               0.778535
# serum_creatinine            0.727413
# liver_enzymes               0.726746
# mean_arterial_pressure      0.682034
# blood_pressure_systolic     0.635392
# blood_pressure_diastolic    0.544651
# bmi                         0.484300
# weight_kg                   0.417944
# urine_creatinine            0.409017
# uterine_artery_pi           0.359440
# heart_rate                  0.260630
# white_blood_cell_count      0.228985
# age                         0.217909
# body_temperature            0.199471
# glucose_level               0.168588
# respiratory_rate            0.166175
# parity                     -0.016284
# height_cm                  -0.037792
# gestational_age_weeks      -0.113685
# red_blood_cell_count       -0.209081
# fetal_heart_rate           -0.290197
# hemoglobin                 -0.334821
# PlGF_level                 -0.490137
# ...
